# %% [markdown]
# # Exploratory Data Analysis: Dimensionality Reduction
#
# ## 1. Algorithms to Try and Read About
#
# Choices:
# - The feature vetors (neurons) are centered to have mean 0, (subtract mean firing rate) and are not normalized.
# - The population array is for all 9 whisker stimulations with each trial = 500 ms after stimulus onset.
#
#
# _Algorithm to Try_
# - staNMF: Bin's suggestion
# - ICA and Sparse Coding
# - Other PCA methods: kPCA weighted PCA
# - look over CRF method

# %% [markdown]
# ### Setting Up

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')
